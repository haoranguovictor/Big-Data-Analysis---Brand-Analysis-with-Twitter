# %% [markdown]
# ___
# ## Imports

# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
sentiment_coco=pd.read_csv('/Users/zym/Documents/bigdata/project/coco_sentiment_tweets.csv')

# %%
sentiment_coco.head()
# Out:
#    month  tweets sentiment  label
# 0      1   33071  positive      0
# 1      1   14222  negative      1
# 2      2   44627  positive      0
# 3      2   16501  negative      1
# 4      3   49109  positive      0

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='month',y='tweets',hue='sentiment',data=sentiment_coco,palette="RdBu_r")

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='sentiment',y='tweets',data=sentiment_coco,palette="coolwarm")

# %%
sentiment_pepsi=pd.read_csv('/Users/zym/Documents/bigdata/project/pepsi_sentiment_tweets.csv')
sentiment_pepsi.head()
# Out:
#    month  tweets sentiment  label
# 0      1   55771  positive      0
# 1      1   26266  negative      1
# 2      2   31449  positive      0
# 3      2   13945  negative      1
# 4      3   47313  positive      0

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='month',y='tweets',hue='sentiment',data=sentiment_pepsi,palette="RdBu_r")

plt.figure(figsize=(8,5))
sns.barplot(x='sentiment',y='tweets',data=sentiment_pepsi,palette="coolwarm")

# %%
sentiment=pd.read_csv('/Users/zym/Documents/bigdata/project/sentiment_tweets.csv')
sentiment.head()
# Out:
#        brand  tweets sentiment  label
# 0  coca_cola  383449  positive      0
# 1  coca_cola  155789  negative      1
# 2      pepsi  473505  positive      0
# 3      pepsi  254633  negative      1

# %%
vals = [383449, 155789]#创建数据系列
vals2 = [473505,254633]
fig = plt.figure(figsize=(8,5))

ax1 = fig.add_axes([0, 0, 0.7, 1]) # main axes
#ax2 = fig.add_axes([0.9, 0.1, 0.8, 0.8]) # inset axes

labels2 = 'positive','negative'
colors = ['#f7caad','#c9e1e9']
colors2 = ['#fdb099','#ccc4e2']
colors3 = ['#f7caad','#c9e1e9','#fdb099','#ccc4e2']
labels1 = ['coca_cola-positive', 'coca_cola-negative','pepsi-positive','pepsi-negative']
#explode = (0, 0.1, 0, 0)


patches, texts1, autotexts = ax1.pie(vals,  colors=colors, labels = labels2, autopct='%1.1f%%',pctdistance=0.7, shadow=True, radius=1.6,
        labeldistance=0.8,textprops={'fontsize':18})
patches, texts2, autotexts = ax1.pie(vals2, colors=colors2,labels = labels2, autopct='%1.1f%%',pctdistance=0.2,shadow=True, radius=1,
        labeldistance=0.4,textprops={'fontsize':18},wedgeprops = { 'linewidth' : 0.5 })

texts2[0].set_fontsize(18)
texts2[1].set_fontsize(18)
texts1[0].set_fontsize(18)
texts1[1].set_fontsize(18)
plt.legend(labels1,bbox_to_anchor=(1.1, 1.08), loc='best', borderaxespad=4.,fontsize='large')
plt.show()

fig.savefig('/Users/zym/Documents/bigdata/project/ratio.png', dpi=200, bbox_inches='tight')
