# %% [markdown]
# ___
# ## Imports

# %%
import seaborn as sns
import pandas as pd

# %matplotlib inline

sns.set()

# %% [markdown]
# ## Data
# Seaborn comes with built-in data sets!

# %%
heat = pd.read_csv('/Users/zym/Documents/bigdata/project/heat_month.csv')

# %%
heat.head()
# Out:
#    month  tweets
# 0      1   47301
# 1      2   61138
# 2      3   60664
# 3      4   65689
# 4      5   58847

# %% [markdown]
# ## jointplot
#
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
sns.jointplot(x='month',y='tweets',data=heat,kind='scatter')

# %%
sns.jointplot(x='month',y='tweets',data=heat,kind='hex')

# %%
pc = sns.jointplot(x='month',y='tweets',data=heat,kind='reg')

pc.savefig('/Users/zym/Documents/bigdata/project/month.png', dpi=200, bbox_inches='tight')

# %%
heat2 = pd.read_csv('/Users/zym/Documents/bigdata/project/heat_month.csv')
